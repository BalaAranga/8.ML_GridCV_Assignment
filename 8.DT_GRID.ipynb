# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
dataset = pd.read_csv("insurance_pre.csv")
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset = pd.get_dummies(dataset,drop_first = True)
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent = dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
dependent = dataset[['charges']]
dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(independent,dependent,test_size=0.30,random_state=0)

# %%
x_train
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 1163   18  28.215         0         0           0
# 196    39  32.800         0         0           0
# 438    52  46.750         5         0           0
# 183    44  26.410         0         0           0
# 1298   33  27.455         2         1           0
# ...   ...     ...       ...       ...         ...
# 763    27  26.030         0         1           0
# 835    42  35.970         2         1           0
# 1216   40  25.080         0         1           0
# 559    19  35.530         0         1           0
# 684    33  18.500         1         0           0
#
# [936 rows x 5 columns]

# %%
# Model creation / learning phase 
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
param_grid = {'criterion' :["mse","mae","friedman_mse"],'max_features':["auto", "sqrt", "log2"],
                         'splitter':["best", "random"]}
grid = GridSearchCV(DecisionTreeRegressor(),param_grid, refit=True, verbose=3, n_jobs=1)
grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# [CV 1/5] END criterion=mse, max_features=auto, splitter=best;, score=0.729 total time=   0.0s
# [CV 2/5] END criterion=mse, max_features=auto, splitter=best;, score=0.558 total time=   0.0s
# [CV 3/5] END criterion=mse, max_features=auto, splitter=best;, score=0.763 total time=   0.0s
# [CV 4/5] END criterion=mse, max_features=auto, splitter=best;, score=0.600 total time=   0.0s
# [CV 5/5] END criterion=mse, max_features=auto, splitter=best;, score=0.649 total time=   0.0s
# [CV 1/5] END criterion=mse, max_features=auto, splitter=random;, score=0.700 total time=   0.0s
# [CV 2/5] END criterion=mse, max_features=auto, splitter=random;, score=0.677 total time=   0.0s
# [CV 3/5] END criterion=mse, max_features=auto, splitter=random;, score=0.624 total time=   0.0s
# [CV 4/5] END criterion=mse, max_features=auto, splitter=random;, score=0.619 total time=   0.0s
# [CV 5/5] END criterion=mse, max_features=auto, splitter=random;, score=0.624 total time=   0.0s
# [CV 1/5] END criterion=mse, max_features=sqrt, splitter=best;, score=0.666 total time=   0.0s
# [CV 2/5] END criterion=mse, max_features=sqrt, splitter=best;, score=0.539 total time=   0.0s
# [CV 3/5] END criterion=mse, max_features=sqrt, splitter=best;, score=0.555 total time=   0.0s
# [CV 4/5] END criterion=mse, max_features=sqrt, splitter=best;, score=0.635 total time=   0.0s
# [CV 5/5] END criterion=mse, max_features=sqrt, splitter=best;, score=0.622 total time=   0.0s
# [CV 1/5] END criterion=mse, max_features=sqrt, splitter=random;, score=0.706 total time=   0.0s
# [CV 2/5] END criterion=mse, max_features=sqrt, splitter=random;, score=0.572 total time=   0.0s
# [CV 3/5] END criterion=mse, max_features=sqrt, splitter=random;, score=0.583 total time=   0.0s
# [CV 4/5] END criterion=mse, max_features=sqrt, splitter=random;, score=0.583 total time=   0.0s
# [CV 5/5] END criterion=mse, max_features=sqrt, splitter=random;, score=0.535 total time=   0.0s
# [CV 1/5] END criterion=mse, max_features=log2, splitter=best;, score=0.715 total time=   0.0s
# [CV 2/5] END criterion=mse, max_features=log2, splitter=best;, score=0.658 total time=   0.0s
# [CV 3/5] END criterion=mse, max_features=log2, splitter=best;, score=0.614 total time=   0.0s
# [CV 4/5] END criterion=mse, max_features=log2, splitter=best;, score=0.607 total time=   0.0s
# [CV 5/5] END criterion=mse, max_features=log2, splitter=best;, score=0.696 total time=   0.0s
# [CV 1/5] END criterion=mse, max_features=log2, splitter=random;, score=0.645 total time=   0.0s
# [CV 2/5] END criterion=mse, max_features=log2, splitter=random;, score=0.591 total time=   0.0s
# [CV 3/5] END criterion=mse, max_features=log2, splitter=random;, score=0.500 total time=   0.0s
# [CV 4/5] END criterion=mse, max_features=log2, splitter=random;, score=0.497 total time=   0.0s
# [CV 5/5] END criterion=mse, max_features=log2, splitter=random;, score=0.626 total time=   0.0s
# [CV 1/5] END criterion=mae, max_features=auto, splitter=best;, score=0.755 total time=   0.0s
# [CV 2/5] END criterion=mae, max_features=auto, splitter=best;, score=0.598 total time=   0.0s
# [CV 3/5] END criterion=mae, max_features=auto, splitter=best;, score=0.607 total time=   0.0s
# [CV 4/5] END criterion=mae, max_features=auto, splitter=best;, score=0.530 total time=   0.0s
# [CV 5/5] END criterion=mae, max_features=auto, splitter=best;, score=0.659 total time=   0.0s
# [CV 1/5] END criterion=mae, max_features=auto, splitter=random;, score=0.588 total time=   0.0s
# [CV 2/5] END criterion=mae, max_features=auto, splitter=random;, score=0.704 total time=   0.0s
# [CV 3/5] END criterion=mae, max_features=auto, splitter=random;, score=0.736 total time=   0.0s
# [CV 4/5] END criterion=mae, max_features=auto, splitter=random;, score=0.654 total time=   0.0s
# [CV 5/5] END criterion=mae, max_features=auto, splitter=random;, score=0.681 total time=   0.0s
# [CV 1/5] END criterion=mae, max_features=sqrt, splitter=best;, score=0.699 total time=   0.0s
# [CV 2/5] END criterion=mae, max_features=sqrt, splitter=best;, score=0.636 total time=   0.0s
# [CV 3/5] END criterion=mae, max_features=sqrt, splitter=best;, score=0.675 total time=   0.0s
# [CV 4/5] END criterion=mae, max_features=sqrt, splitter=best;, score=0.643 total time=   0.0s
# [CV 5/5] END criterion=mae, max_features=sqrt, splitter=best;, score=0.628 total time=   0.0s
# [CV 1/5] END criterion=mae, max_features=sqrt, splitter=random;, score=0.681 total time=   0.0s
# [CV 2/5] END criterion=mae, max_features=sqrt, splitter=random;, score=0.549 total time=   0.0s
# [CV 3/5] END criterion=mae, max_features=sqrt, splitter=random;, score=0.672 total time=   0.0s
# [CV 4/5] END criterion=mae, max_features=sqrt, splitter=random;, score=0.676 total time=   0.0s
# [CV 5/5] END criterion=mae, max_features=sqrt, splitter=random;, score=0.470 total time=   0.0s
# [CV 1/5] END criterion=mae, max_features=log2, splitter=best;, score=0.601 total time=   0.0s
# [CV 2/5] END criterion=mae, max_features=log2, splitter=best;, score=0.583 total time=   0.0s
# [CV 3/5] END criterion=mae, max_features=log2, splitter=best;, score=0.643 total time=   0.0s
# [CV 4/5] END criterion=mae, max_features=log2, splitter=best;, score=0.662 total time=   0.0s
# [CV 5/5] END criterion=mae, max_features=log2, splitter=best;, score=0.660 total time=   0.0s
# [CV 1/5] END criterion=mae, max_features=log2, splitter=random;, score=0.625 total time=   0.0s
# [CV 2/5] END criterion=mae, max_features=log2, splitter=random;, score=0.663 total time=   0.0s
# [CV 3/5] END criterion=mae, max_features=log2, splitter=random;, score=0.700 total time=   0.0s
# [CV 4/5] END criterion=mae, max_features=log2, splitter=random;, score=0.492 total time=   0.0s
# [CV 5/5] END criterion=mae, max_features=log2, splitter=random;, score=0.636 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_features=auto, splitter=best;, score=0.746 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_features=auto, splitter=best;, score=0.537 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_features=auto, splitter=best;, score=0.771 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_features=auto, splitter=best;, score=0.616 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_features=auto, splitter=best;, score=0.679 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_features=auto, splitter=random;, score=0.722 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_features=auto, splitter=random;, score=0.625 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_features=auto, splitter=random;, score=0.649 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_features=auto, splitter=random;, score=0.625 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_features=auto, splitter=random;, score=0.617 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_features=sqrt, splitter=best;, score=0.646 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_features=sqrt, splitter=best;, score=0.626 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_features=sqrt, splitter=best;, score=0.719 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_features=sqrt, splitter=best;, score=0.686 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_features=sqrt, splitter=best;, score=0.570 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_features=sqrt, splitter=random;, score=0.623 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_features=sqrt, splitter=random;, score=0.628 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_features=sqrt, splitter=random;, score=0.586 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_features=sqrt, splitter=random;, score=0.550 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_features=sqrt, splitter=random;, score=0.548 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_features=log2, splitter=best;, score=0.719 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_features=log2, splitter=best;, score=0.687 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_features=log2, splitter=best;, score=0.624 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_features=log2, splitter=best;, score=0.693 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_features=log2, splitter=best;, score=0.560 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_features=log2, splitter=random;, score=0.679 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_features=log2, splitter=random;, score=0.661 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_features=log2, splitter=random;, score=0.475 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_features=log2, splitter=random;, score=0.641 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_features=log2, splitter=random;, score=0.618 total time=   0.0s
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=1,
#              param_grid={'criterion': ['mse', 'mae', 'friedman_mse'],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
# print best parameter after tuning
# print(grid.best_params_)
re = grid.cv_results_
grid_prediction = grid.predict(x_test)
# print classification report
from sklearn.metrics import r2_score
r_score = r2_score(y_test,grid_prediction)
print("The R Score Value for Best Parameter {}:".format(grid.best_params_),r_score)
# Out:
# The R Score Value for Best Parameter {'criterion': 'mae', 'max_features': 'auto', 'splitter': 'random'}: 0.7740393410944832

# %%
table = pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.002802      0.001918         0.001400        0.001199
# 1        0.003130      0.006259         0.003124        0.006249
# 2        0.006249      0.007653         0.000000        0.000000
# 3        0.001596      0.001954         0.006639        0.006576
# 4        0.003989      0.000002         0.001816        0.000358
# 5        0.003130      0.006259         0.000000        0.000000
# 6        0.008919      0.007575         0.007660        0.006511
# 7        0.012502      0.006251         0.000000        0.000000
# 8        0.007287      0.008595         0.003523        0.006101
# 9        0.007925      0.001961         0.002312        0.000392
# 10       0.009379      0.007658         0.000000        0.000000
# 11       0.009373      0.007653         0.000000        0.000000
# 12       0.006248      0.007652         0.003125        0.006250
# 13       0.001814      0.002247         0.004658        0.005465
# 14       0.003208      0.001123         0.001599        0.000800
# 15       0.003124      0.006247         0.003131        0.006262
# 16       0.003124      0.006248         0.003124        0.006249
# 17       0.003124      0.006248         0.003124        0.006248
#
#    param_criterion param_max_features param_splitter  \
# 0              mse               auto           best
# 1              mse               auto         random
# 2              mse               sqrt           best
# 3              mse               sqrt         random
# 4              mse               log2           best
# 5              mse               log2         random
# 6              mae               auto           best
# 7              mae               auto         random
# 8              mae               sqrt           best
# 9              mae               sqrt         random
# 10             mae               log2           best
# 11             mae               log2         random
# 12    friedman_mse               auto           best
# 13    friedman_mse               auto         random
# 14    friedman_mse               sqrt           best
# 15    friedman_mse               sqrt         random
# 16    friedman_mse               log2           best
# 17    friedman_mse               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'mse', 'max_features': 'auto', '...           0.728697
# 1   {'criterion': 'mse', 'max_features': 'auto', '...           0.699508
# 2   {'criterion': 'mse', 'max_features': 'sqrt', '...           0.666413
# 3   {'criterion': 'mse', 'max_features': 'sqrt', '...           0.705767
# 4   {'criterion': 'mse', 'max_features': 'log2', '...           0.714914
# 5   {'criterion': 'mse', 'max_features': 'log2', '...           0.644652
# 6   {'criterion': 'mae', 'max_features': 'auto', '...           0.755026
# 7   {'criterion': 'mae', 'max_features': 'auto', '...           0.587752
# 8   {'criterion': 'mae', 'max_features': 'sqrt', '...           0.699306
# 9   {'criterion': 'mae', 'max_features': 'sqrt', '...           0.680517
# 10  {'criterion': 'mae', 'max_features': 'log2', '...           0.601412
# 11  {'criterion': 'mae', 'max_features': 'log2', '...           0.624992
# 12  {'criterion': 'friedman_mse', 'max_features': ...           0.745627
# 13  {'criterion': 'friedman_mse', 'max_features': ...           0.722110
# 14  {'criterion': 'friedman_mse', 'max_features': ...           0.646384
# 15  {'criterion': 'friedman_mse', 'max_features': ...           0.623457
# 16  {'criterion': 'friedman_mse', 'max_features': ...           0.719226
# 17  {'criterion': 'friedman_mse', 'max_features': ...           0.679499
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.557520           0.762642           0.600126
# 1            0.676889           0.624456           0.618819
# 2            0.539461           0.554642           0.635112
# 3            0.572359           0.582612           0.583205
# 4            0.657600           0.613756           0.606598
# 5            0.591090           0.499754           0.497301
# 6            0.598074           0.607141           0.529692
# 7            0.703520           0.736255           0.653560
# 8            0.636453           0.675247           0.643216
# 9            0.549436           0.672094           0.675642
# 10           0.583339           0.642831           0.662031
# 11           0.662785           0.699500           0.492284
# 12           0.536855           0.770879           0.615753
# 13           0.625219           0.649350           0.624614
# 14           0.625948           0.718727           0.685503
# 15           0.627633           0.585660           0.550376
# 16           0.686559           0.624454           0.692507
# 17           0.661357           0.475042           0.640706
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.649429         0.659683        0.076750                3
# 1            0.624170         0.648768        0.033041                8
# 2            0.622129         0.603551        0.048564               15
# 3            0.535480         0.595884        0.057643               16
# 4            0.696430         0.657860        0.043165                4
# 5            0.626475         0.571854        0.062305               18
# 6            0.658875         0.629762        0.074925               11
# 7            0.681024         0.672422        0.050280                1
# 8            0.627551         0.656355        0.026833                6
# 9            0.470320         0.609602        0.085223               14
# 10           0.660346         0.629992        0.031956               10
# 11           0.636409         0.623194        0.070293               12
# 12           0.678777         0.669578        0.085607                2
# 13           0.617339         0.647726        0.038729                9
# 14           0.569674         0.649247        0.051039                7
# 15           0.548486         0.587122        0.034078               17
# 16           0.559641         0.656478        0.057521                5
# 17           0.618255         0.614972        0.072896               13

# %%
age_input = float(input("Age :"))
bmi_input = float(input("BMI :"))
children_input = float(input("Children :"))
sex_male_input = int(input("Sex Male 0 or 1 :"))
smoker_yes_input = int(input("Smoker_yes 0 or 1 :"))
# Out:
# Age :25
# BMI :30
# Children :2
# Sex Male 0 or 1 :1
# Smoker_yes 0 or 1 :0

# %%
Future_Prediction = grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Future_Prediction {}:".format(Future_Prediction))
# Out:
# Future_Prediction [3877.30425]:

# %%
#import pickle
#filename = "DT_GRID.sav"

# %%
#pickle.dump(grid,open(filename,"wb"))
