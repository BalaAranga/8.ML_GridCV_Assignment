# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
dataset = pd.read_csv("insurance_pre.csv")
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset = pd.get_dummies(dataset,drop_first = True)
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent = dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]

# %%
dependent = dataset[['charges']]

# %%
# Model creation / learning phase 
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
param_grid = {'criterion' :["mse","mae","friedman_mse"],'max_features':["auto", "sqrt", "log2"],
                         'splitter':["best", "random"]}
grid = GridSearchCV(DecisionTreeRegressor(),param_grid, refit=True, verbose=3, n_jobs=1)
grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# [CV 1/5] END criterion=mse, max_features=auto, splitter=best;, score=0.716 total time=   0.0s
# [CV 2/5] END criterion=mse, max_features=auto, splitter=best;, score=0.634 total time=   0.0s
# [CV 3/5] END criterion=mse, max_features=auto, splitter=best;, score=0.740 total time=   0.0s
# [CV 4/5] END criterion=mse, max_features=auto, splitter=best;, score=0.723 total time=   0.0s
# [CV 5/5] END criterion=mse, max_features=auto, splitter=best;, score=0.677 total time=   0.0s
# [CV 1/5] END criterion=mse, max_features=auto, splitter=random;, score=0.606 total time=   0.0s
# [CV 2/5] END criterion=mse, max_features=auto, splitter=random;, score=0.537 total time=   0.0s
# [CV 3/5] END criterion=mse, max_features=auto, splitter=random;, score=0.720 total time=   0.0s
# [CV 4/5] END criterion=mse, max_features=auto, splitter=random;, score=0.743 total time=   0.0s
# [CV 5/5] END criterion=mse, max_features=auto, splitter=random;, score=0.731 total time=   0.0s
# [CV 1/5] END criterion=mse, max_features=sqrt, splitter=best;, score=0.633 total time=   0.0s
# [CV 2/5] END criterion=mse, max_features=sqrt, splitter=best;, score=0.567 total time=   0.0s
# [CV 3/5] END criterion=mse, max_features=sqrt, splitter=best;, score=0.802 total time=   0.0s
# [CV 4/5] END criterion=mse, max_features=sqrt, splitter=best;, score=0.730 total time=   0.0s
# [CV 5/5] END criterion=mse, max_features=sqrt, splitter=best;, score=0.753 total time=   0.0s
# [CV 1/5] END criterion=mse, max_features=sqrt, splitter=random;, score=0.637 total time=   0.0s
# [CV 2/5] END criterion=mse, max_features=sqrt, splitter=random;, score=0.523 total time=   0.0s
# [CV 3/5] END criterion=mse, max_features=sqrt, splitter=random;, score=0.462 total time=   0.0s
# [CV 4/5] END criterion=mse, max_features=sqrt, splitter=random;, score=0.623 total time=   0.0s
# [CV 5/5] END criterion=mse, max_features=sqrt, splitter=random;, score=0.638 total time=   0.0s
# [CV 1/5] END criterion=mse, max_features=log2, splitter=best;, score=0.686 total time=   0.0s
# [CV 2/5] END criterion=mse, max_features=log2, splitter=best;, score=0.561 total time=   0.0s
# [CV 3/5] END criterion=mse, max_features=log2, splitter=best;, score=0.666 total time=   0.0s
# [CV 4/5] END criterion=mse, max_features=log2, splitter=best;, score=0.710 total time=   0.0s
# [CV 5/5] END criterion=mse, max_features=log2, splitter=best;, score=0.783 total time=   0.0s
# [CV 1/5] END criterion=mse, max_features=log2, splitter=random;, score=0.616 total time=   0.0s
# [CV 2/5] END criterion=mse, max_features=log2, splitter=random;, score=0.640 total time=   0.0s
# [CV 3/5] END criterion=mse, max_features=log2, splitter=random;, score=0.626 total time=   0.0s
# [CV 4/5] END criterion=mse, max_features=log2, splitter=random;, score=0.695 total time=   0.0s
# [CV 5/5] END criterion=mse, max_features=log2, splitter=random;, score=0.647 total time=   0.0s
# [CV 1/5] END criterion=mae, max_features=auto, splitter=best;, score=0.730 total time=   0.0s
# [CV 2/5] END criterion=mae, max_features=auto, splitter=best;, score=0.597 total time=   0.0s
# [CV 3/5] END criterion=mae, max_features=auto, splitter=best;, score=0.714 total time=   0.0s
# [CV 4/5] END criterion=mae, max_features=auto, splitter=best;, score=0.715 total time=   0.0s
# [CV 5/5] END criterion=mae, max_features=auto, splitter=best;, score=0.744 total time=   0.0s
# [CV 1/5] END criterion=mae, max_features=auto, splitter=random;, score=0.744 total time=   0.0s
# [CV 2/5] END criterion=mae, max_features=auto, splitter=random;, score=0.672 total time=   0.0s
# [CV 3/5] END criterion=mae, max_features=auto, splitter=random;, score=0.717 total time=   0.0s
# [CV 4/5] END criterion=mae, max_features=auto, splitter=random;, score=0.721 total time=   0.0s
# [CV 5/5] END criterion=mae, max_features=auto, splitter=random;, score=0.703 total time=   0.0s
# [CV 1/5] END criterion=mae, max_features=sqrt, splitter=best;, score=0.715 total time=   0.0s
# [CV 2/5] END criterion=mae, max_features=sqrt, splitter=best;, score=0.651 total time=   0.0s
# [CV 3/5] END criterion=mae, max_features=sqrt, splitter=best;, score=0.516 total time=   0.0s
# [CV 4/5] END criterion=mae, max_features=sqrt, splitter=best;, score=0.676 total time=   0.0s
# [CV 5/5] END criterion=mae, max_features=sqrt, splitter=best;, score=0.568 total time=   0.0s
# [CV 1/5] END criterion=mae, max_features=sqrt, splitter=random;, score=0.686 total time=   0.0s
# [CV 2/5] END criterion=mae, max_features=sqrt, splitter=random;, score=0.581 total time=   0.0s
# [CV 3/5] END criterion=mae, max_features=sqrt, splitter=random;, score=0.696 total time=   0.0s
# [CV 4/5] END criterion=mae, max_features=sqrt, splitter=random;, score=0.658 total time=   0.0s
# [CV 5/5] END criterion=mae, max_features=sqrt, splitter=random;, score=0.690 total time=   0.0s
# [CV 1/5] END criterion=mae, max_features=log2, splitter=best;, score=0.676 total time=   0.0s
# [CV 2/5] END criterion=mae, max_features=log2, splitter=best;, score=0.631 total time=   0.0s
# [CV 3/5] END criterion=mae, max_features=log2, splitter=best;, score=0.706 total time=   0.0s
# [CV 4/5] END criterion=mae, max_features=log2, splitter=best;, score=0.658 total time=   0.0s
# [CV 5/5] END criterion=mae, max_features=log2, splitter=best;, score=0.680 total time=   0.0s
# [CV 1/5] END criterion=mae, max_features=log2, splitter=random;, score=0.643 total time=   0.0s
# [CV 2/5] END criterion=mae, max_features=log2, splitter=random;, score=0.615 total time=   0.0s
# [CV 3/5] END criterion=mae, max_features=log2, splitter=random;, score=0.622 total time=   0.0s
# [CV 4/5] END criterion=mae, max_features=log2, splitter=random;, score=0.661 total time=   0.0s
# [CV 5/5] END criterion=mae, max_features=log2, splitter=random;, score=0.657 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_features=auto, splitter=best;, score=0.709 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_features=auto, splitter=best;, score=0.650 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_features=auto, splitter=best;, score=0.738 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_features=auto, splitter=best;, score=0.745 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_features=auto, splitter=best;, score=0.683 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_features=auto, splitter=random;, score=0.673 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_features=auto, splitter=random;, score=0.548 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_features=auto, splitter=random;, score=0.705 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_features=auto, splitter=random;, score=0.758 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_features=auto, splitter=random;, score=0.729 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_features=sqrt, splitter=best;, score=0.702 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_features=sqrt, splitter=best;, score=0.545 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_features=sqrt, splitter=best;, score=0.748 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_features=sqrt, splitter=best;, score=0.667 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_features=sqrt, splitter=best;, score=0.698 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_features=sqrt, splitter=random;, score=0.727 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_features=sqrt, splitter=random;, score=0.496 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_features=sqrt, splitter=random;, score=0.678 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_features=sqrt, splitter=random;, score=0.728 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_features=sqrt, splitter=random;, score=0.687 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_features=log2, splitter=best;, score=0.749 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_features=log2, splitter=best;, score=0.583 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_features=log2, splitter=best;, score=0.704 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_features=log2, splitter=best;, score=0.692 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_features=log2, splitter=best;, score=0.717 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_features=log2, splitter=random;, score=0.609 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_features=log2, splitter=random;, score=0.612 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_features=log2, splitter=random;, score=0.667 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_features=log2, splitter=random;, score=0.593 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_features=log2, splitter=random;, score=0.604 total time=   0.0s
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=1,
#              param_grid={'criterion': ['mse', 'mae', 'friedman_mse'],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
re = grid.cv_results_
print("The R Score Value for Best Parameter {}:".format(grid.best_params_))
# Out:
# The R Score Value for Best Parameter {'criterion': 'mae', 'max_features': 'auto', 'splitter': 'random'}:

# %%
table = pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.003125      0.006250         0.000000        0.000000
# 1        0.006246      0.007650         0.000000        0.000000
# 2        0.006249      0.007653         0.000000        0.000000
# 3        0.006250      0.007655         0.000000        0.000000
# 4        0.003124      0.006249         0.003123        0.006246
# 5        0.003124      0.006248         0.004859        0.006344
# 6        0.021678      0.005246         0.000798        0.000977
# 7        0.017357      0.003473         0.000605        0.001209
# 8        0.005186      0.006383         0.010263        0.006592
# 9        0.009373      0.007653         0.003125        0.006250
# 10       0.015640      0.010472         0.000997        0.001261
# 11       0.010882      0.006286         0.000000        0.000000
# 12       0.006247      0.007651         0.003123        0.006247
# 13       0.005836      0.006656         0.001394        0.001192
# 14       0.002614      0.001725         0.001399        0.001198
# 15       0.005251      0.005387         0.003206        0.002838
# 16       0.002476      0.001845         0.001404        0.001201
# 17       0.003130      0.006259         0.000000        0.000000
#
#    param_criterion param_max_features param_splitter  \
# 0              mse               auto           best
# 1              mse               auto         random
# 2              mse               sqrt           best
# 3              mse               sqrt         random
# 4              mse               log2           best
# 5              mse               log2         random
# 6              mae               auto           best
# 7              mae               auto         random
# 8              mae               sqrt           best
# 9              mae               sqrt         random
# 10             mae               log2           best
# 11             mae               log2         random
# 12    friedman_mse               auto           best
# 13    friedman_mse               auto         random
# 14    friedman_mse               sqrt           best
# 15    friedman_mse               sqrt         random
# 16    friedman_mse               log2           best
# 17    friedman_mse               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'mse', 'max_features': 'auto', '...           0.716385
# 1   {'criterion': 'mse', 'max_features': 'auto', '...           0.605606
# 2   {'criterion': 'mse', 'max_features': 'sqrt', '...           0.632626
# 3   {'criterion': 'mse', 'max_features': 'sqrt', '...           0.636646
# 4   {'criterion': 'mse', 'max_features': 'log2', '...           0.685544
# 5   {'criterion': 'mse', 'max_features': 'log2', '...           0.616201
# 6   {'criterion': 'mae', 'max_features': 'auto', '...           0.729756
# 7   {'criterion': 'mae', 'max_features': 'auto', '...           0.744287
# 8   {'criterion': 'mae', 'max_features': 'sqrt', '...           0.715165
# 9   {'criterion': 'mae', 'max_features': 'sqrt', '...           0.686094
# 10  {'criterion': 'mae', 'max_features': 'log2', '...           0.675502
# 11  {'criterion': 'mae', 'max_features': 'log2', '...           0.643476
# 12  {'criterion': 'friedman_mse', 'max_features': ...           0.709055
# 13  {'criterion': 'friedman_mse', 'max_features': ...           0.673377
# 14  {'criterion': 'friedman_mse', 'max_features': ...           0.701811
# 15  {'criterion': 'friedman_mse', 'max_features': ...           0.727417
# 16  {'criterion': 'friedman_mse', 'max_features': ...           0.748689
# 17  {'criterion': 'friedman_mse', 'max_features': ...           0.609444
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.633843           0.740023           0.723038
# 1            0.537345           0.720003           0.742772
# 2            0.566703           0.802010           0.729525
# 3            0.522506           0.461547           0.622862
# 4            0.561154           0.665945           0.710390
# 5            0.639682           0.626112           0.694982
# 6            0.597210           0.713995           0.715144
# 7            0.671837           0.716877           0.721382
# 8            0.650981           0.515529           0.675845
# 9            0.581432           0.696354           0.657662
# 10           0.630578           0.706266           0.657919
# 11           0.615037           0.621522           0.661095
# 12           0.649718           0.737752           0.745469
# 13           0.548435           0.704791           0.758381
# 14           0.545299           0.748042           0.667058
# 15           0.496212           0.677738           0.728433
# 16           0.582504           0.704233           0.691762
# 17           0.612381           0.667243           0.593216
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.676589         0.697975        0.038224                4
# 1            0.731044         0.667354        0.081525               11
# 2            0.752735         0.696720        0.085220                5
# 3            0.638244         0.576361        0.071706               18
# 4            0.783329         0.681272        0.072035                8
# 5            0.647200         0.644836        0.027266               14
# 6            0.743907         0.700002        0.052544                3
# 7            0.702653         0.711407        0.023887                1
# 8            0.567977         0.625099        0.072973               16
# 9            0.690327         0.662374        0.042597               13
# 10           0.679545         0.669962        0.025046               10
# 11           0.656785         0.639583        0.018453               15
# 12           0.682611         0.704921        0.035452                2
# 13           0.729208         0.682838        0.072791                7
# 14           0.698215         0.672085        0.068463                9
# 15           0.686988         0.663358        0.086071               12
# 16           0.717215         0.688881        0.056462                6
# 17           0.604311         0.617319        0.025803               17

# %%
age_input = float(input("Age :"))
bmi_input = float(input("BMI :"))
children_input = float(input("Children :"))
sex_male_input = int(input("Sex Male 0 or 1 :"))
smoker_yes_input = int(input("Smoker_yes 0 or 1 :"))
# Out:
# Age :25
# BMI :30
# Children :2
# Sex Male 0 or 1 :0
# Smoker_yes 0 or 1 :1

# %%
Future_Prediction = grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Future_Prediction {}:".format(Future_Prediction))
# Out:
# Future_Prediction [33307.5508]:

# %%
#import pickle
#filename = "DT_GRID_Without Training and Testing.sav"

# %%
#pickle.dump(grid,open(filename,"wb"))
