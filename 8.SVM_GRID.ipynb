# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
dataset = pd.read_csv("insurance_pre.csv")
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset = pd.get_dummies(dataset,drop_first = True)
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent = dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
dependent = dataset[['charges']]
dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(independent,dependent,test_size=0.30,random_state=0)

# %%
# standardisation
from sklearn.preprocessing import StandardScaler # procedure
sc = StandardScaler() # procedure
x_train =sc.fit_transform(x_train) # fit will do calculation ,transform will tranform data also
x_test =sc.transform(x_test) # here not required fit for x_test , what we used for fit x_train it will take

# %%
x_train
# Out:
# array([[-1.5330973 , -0.40713453, -0.89833872, -0.97676557, -0.50466988],
#        [-0.03364163,  0.32855417, -0.89833872, -0.97676557, -0.50466988],
#        [ 0.89459283,  2.56690911,  3.25603402, -0.97676557, -0.50466988],
#        ...,
#        [ 0.03776102, -0.91016269, -0.89833872,  1.02378711, -0.50466988],
#        [-1.46169465,  0.76659782, -0.89833872,  1.02378711, -0.50466988],
#        [-0.46205754, -1.96596021, -0.06746417, -0.97676557, -0.50466988]])

# %%
# Model creation / learning phase 
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR

param_grid = {'kernel' :['linear', 'poly', 'rbf', 'sigmoid'],'C':[10,100,1000,2000,3000],
                         'gamma':['scale', 'auto']}
grid = GridSearchCV(SVR(),param_grid, refit=True, verbose=3, n_jobs=1)
grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# [CV 1/5] END ..C=10, gamma=scale, kernel=linear;, score=0.378 total time=   0.0s
# [CV 2/5] END ..C=10, gamma=scale, kernel=linear;, score=0.480 total time=   0.0s
# [CV 3/5] END ..C=10, gamma=scale, kernel=linear;, score=0.318 total time=   0.0s
# [CV 4/5] END ..C=10, gamma=scale, kernel=linear;, score=0.338 total time=   0.0s
# [CV 5/5] END ..C=10, gamma=scale, kernel=linear;, score=0.324 total time=   0.0s
# [CV 1/5] END ....C=10, gamma=scale, kernel=poly;, score=0.055 total time=   0.0s
# [CV 2/5] END ....C=10, gamma=scale, kernel=poly;, score=0.071 total time=   0.0s
# [CV 3/5] END ...C=10, gamma=scale, kernel=poly;, score=-0.047 total time=   0.0s
# [CV 4/5] END ...C=10, gamma=scale, kernel=poly;, score=-0.024 total time=   0.0s
# [CV 5/5] END ...C=10, gamma=scale, kernel=poly;, score=-0.050 total time=   0.0s
# [CV 1/5] END .....C=10, gamma=scale, kernel=rbf;, score=0.004 total time=   0.0s
# ...

# %%
re = grid.cv_results_
print("The R Score Value for Best Parameter {}:".format(grid.best_params_))
# Out:
# The R Score Value for Best Parameter {'C': 3000, 'gamma': 'scale', 'kernel': 'poly'}:

# %%
table = pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0        0.017420      0.002594         0.004529        0.005772      10
# 1        0.019371      0.006058         0.005666        0.005924      10
# 2        0.028431      0.008204         0.007372        0.005627      10
# 3        0.027144      0.006712         0.007445        0.007024      10
# 4        0.019349      0.005674         0.001596        0.001955      10
# 5        0.021870      0.007652         0.003124        0.006248      10
# 6        0.028413      0.007855         0.009663        0.005181      10
# 7        0.024000      0.006297         0.010039        0.004573      10
# 8        0.021519      0.009399         0.004720        0.005736     100
# 9        0.022471      0.008443         0.003922        0.006050     100
# 10       0.023945      0.005292         0.011967        0.003087     100
# 11       0.032561      0.005355         0.001197        0.002394     100
# ...

# %%
regressor = SVR(C= 3000, gamma= 'scale', kernel= 'poly') 
regressor.fit(x_train,y_train)
# Out:
# SVR(C=3000, kernel='poly')

# %%
y_pred = regressor.predict(x_test) # AI Brain giving output(predicting)
y_pred
# Out:
# array([ 9882.23553045,  8684.53726052, 47863.91492801, 12571.3296839 ,
#        10503.41343965,  4754.93723666,  1443.94974332, 11161.657231  ,
#         7435.84538836,  5371.62749203,  6792.36540753, 10061.14110577,
#         7632.07502973,  4871.76871538, 25340.31666642, 10702.78951231,
#        12523.59208886,  3559.80058082,  6538.68332237, 24014.94367286,
#        25935.15514706, 12148.61708249,  9691.29174851, 30533.71413143,
#         1963.47262983,  4967.98361807,  4445.33159778,  8003.49970394,
#         4385.68529386,  8313.99557978,  7894.30531574, 51334.29195097,
#        13004.91484206, 10251.92921715, 12711.42308371,  4153.88138193,
#         8739.42694068, 35968.17012455, 35436.61473362,  2077.05999458,
#         5945.32507383,  3376.59733561, 27298.90556466, 44665.58571445,
#        32712.02939249,  3248.44366366, 10704.52721091,  7044.43520973,
#         4729.54504139, 12142.93055349,  2793.08923534,  2960.73592137,
# ...

# %%
from sklearn.metrics import r2_score
r_score = r2_score(y_test,y_pred)

# %%
r_score
# Out:
# 0.8598930084494358

# %%
age_input = float(input("Age :"))
bmi_input = float(input("BMI :"))
children_input = float(input("Children :"))
sex_male_input = int(input("Sex Male 0 or 1 :"))
smoker_yes_input = int(input("Smoker_yes 0 or 1 :"))
# Out:
# Age :25
# BMI :30
# Children :2
# Sex Male 0 or 1 :0
# Smoker_yes 0 or 1 :1

# %%
Future_Prediction = grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Future_Prediction {}:".format(Future_Prediction))
# Out:
# Future_Prediction [1537847.86499158]:

# %%
#import pickle
#filename = "SVR_GRID.sav"

# %%
#pickle.dump(grid,open(filename,"wb"))
