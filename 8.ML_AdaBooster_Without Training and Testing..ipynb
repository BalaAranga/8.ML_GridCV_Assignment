# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
dataset = pd.read_csv("insurance_pre.csv")
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset = pd.get_dummies(dataset,drop_first = True)
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent = dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
dependent = dataset[['charges']]
dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import AdaBoostRegressor # procedure
param_grid = {'n_estimators' :[50,100,200,500],'learning_rate':[1,2,5],'loss':["linear","square","exponential"],
                         'random_state':[1,2]}
grid = GridSearchCV(AdaBoostRegressor(),param_grid, refit=True, verbose=3, n_jobs=1)
grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# [CV 1/5] END learning_rate=1, loss=linear, n_estimators=50, random_state=1;, score=0.842 total time=   0.0s
# [CV 2/5] END learning_rate=1, loss=linear, n_estimators=50, random_state=1;, score=0.774 total time=   0.0s
# [CV 3/5] END learning_rate=1, loss=linear, n_estimators=50, random_state=1;, score=0.839 total time=   0.0s
# [CV 4/5] END learning_rate=1, loss=linear, n_estimators=50, random_state=1;, score=0.823 total time=   0.0s
# [CV 5/5] END learning_rate=1, loss=linear, n_estimators=50, random_state=1;, score=0.823 total time=   0.0s
# [CV 1/5] END learning_rate=1, loss=linear, n_estimators=50, random_state=2;, score=0.834 total time=   0.0s
# [CV 2/5] END learning_rate=1, loss=linear, n_estimators=50, random_state=2;, score=0.785 total time=   0.0s
# [CV 3/5] END learning_rate=1, loss=linear, n_estimators=50, random_state=2;, score=0.837 total time=   0.0s
# ...

# %%
re = grid.cv_results_
print("The R Score Value for Best Parameter {}:".format(grid.best_params_))
# Out:
# The R Score Value for Best Parameter {'learning_rate': 2, 'loss': 'linear', 'n_estimators': 50, 'random_state': 2}:

# %%
table = pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.008936      0.005780         0.003128        0.003936
# 1        0.015622      0.000004         0.000000        0.000000
# 2        0.003124      0.006247         0.009372        0.007653
# 3        0.013412      0.008800         0.001796        0.001466
# 4        0.015627      0.000007         0.000000        0.000000
# ..            ...           ...              ...             ...
# 67       0.088245      0.008319         0.012498        0.006249
# 68       0.174149      0.007335         0.015622        0.000002
# 69       0.176899      0.004144         0.012498        0.006249
# 70       0.427712      0.007100         0.031244        0.000005
# 71       0.428978      0.007946         0.031244        0.000007
#
#    param_learning_rate   param_loss param_n_estimators param_random_state  \
# 0                    1       linear                 50                  1
# ...

# %%
age_input = float(input("Age :"))
bmi_input = float(input("BMI :"))
children_input = float(input("Children :"))
sex_male_input = int(input("Sex Male 0 or 1 :"))
smoker_yes_input = int(input("Smoker_yes 0 or 1 :"))
# Out:
# Age :25
# BMI :30
# Children :2
# Sex Male 0 or 1 :0
# Smoker_yes 0 or 1 :1

# %%
Future_Prediction = grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Future_Prediction {}:".format(Future_Prediction))
# Out:
# Future_Prediction [18180.87018882]:

# %%
#import pickle
#filename = "AdaBooster_Without Training and Testing.sav" 
#pickle.dump(grid,open(filename,"wb"))
